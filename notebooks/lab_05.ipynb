# %% [markdown]
# # Lab 5: Project Roadmap
#
# In this assignment, you will advance your course project by creating a roadmap of tasks and performing a critical exploratory analysis of your dataset.

# %%
# --- Import Libraries ---
# additional libraries need to be added to the requirements.txt file (see README.md for more details)
import pandas as pd
import numpy as np

# %% [markdown]
# ## Part 1: Data Ingestion & Reality Check (1.5 Points)
#
# Your first task is to load the data and verify that it matches your mental model of the dataset.

# %%
# TODO: Load your dataset
df = pd.read_csv('../data/amazon.csv')

# %%
# TODO: Print the shape (rows, columns)
df.shape
df.head()
# Out:
#    order_id  order_date  product_id product_category   price  \
# 0         1  2022-04-13        2637            Books  128.75
# 1         2  2023-03-12        2300          Fashion  302.60
# 2         3  2022-09-28        3670           Sports  495.80
# 3         4  2022-04-17        2522            Books  371.95
# 4         5  2022-03-13        1717           Beauty  201.68
#
#    discount_percent  quantity_sold customer_region payment_method  rating  \
# 0                10              4   North America            UPI     3.5
# 1                20              5            Asia    Credit Card     3.7
# 2                20              2          Europe            UPI     4.4
# 3                15              4     Middle East            UPI     5.0
# 4                 0              4     Middle East            UPI     4.6
#
#    review_count  discounted_price  total_revenue
# 0           443            115.88         463.52
# 1           475            242.08        1210.40
# ...

# %%
# TODO: Clean up your Column Names (rename them to remove spaces if needed)
# Example: df = df.rename(columns={'Old Name': 'new_name'})
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ", "_")
)

# %%
# TODO: Fix Date Columns (if applicable)
# Example: df['date_col'] = pd.to_datetime(df['date_col'])
df["order_date"] = pd.to_datetime(df["order_date"])
# Out:
# ['order_id', 'order_date', 'product_id', 'product_category', 'price', 'discount_percent', 'quantity_sold', 'customer_region', 'payment_method', 'rating', 'review_count', 'discounted_price', 'total_revenue']

# %% [markdown]
# **Part 1 Analysis:**
# *Double click here to edit.*
# 1. Does the row count match your expectation?
# 2. Did the column renaming work?
# 3. Have you changed any of the variable data types?

# %%
# TODO: Display the first 10-20 rows (head) and last 5 rows (tail) of your dataframe
df.head()
df.tail()
# Out:
#        order_id order_date  product_id product_category   price  \
# 49995     49996 2022-09-03        1433           Beauty   26.99
# 49996     49997 2022-07-03        1428           Beauty  294.23
# 49997     49998 2023-02-17        4651      Electronics  352.11
# 49998     49999 2022-09-30        4371           Beauty  307.54
# 49999     50000 2023-06-29        2944   Home & Kitchen  253.44
#
#        discount_percent  quantity_sold customer_region payment_method  rating  \
# 49995                 0              5     Middle East    Credit Card     2.4
# 49996                10              5            Asia    Credit Card     3.1
# 49997                30              4            Asia     Debit Card     3.1
# 49998                 5              1     Middle East            UPI     1.8
# 49999                30              1          Europe     Debit Card     2.1
#
#        review_count  discounted_price  total_revenue
# 49995           386             26.99         134.95
# ...

# %% [markdown]
# **Visual Inspection:**
# *Double click here to edit.*
# 1. Do the headers look correct?
# 2. Does the data at the bottom of the file look consistent with the top?

# %% [markdown]
# ## Part 2: Deep Dive & Data Dictionary (2 Points)
# You will now analyze the content of each column to build a "Data Dictionary" and assess data quality

# %%
# TODO: Use .describe(), .info(), or .unique() to analyze your columns
df.info()
df.describe(include="all")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          50000 non-null  int64
#  1   order_date        50000 non-null  datetime64[us]
#  2   product_id        50000 non-null  int64
#  3   product_category  50000 non-null  str
#  4   price             50000 non-null  float64
#  5   discount_percent  50000 non-null  int64
#  6   quantity_sold     50000 non-null  int64
#  7   customer_region   50000 non-null  str
#  8   payment_method    50000 non-null  str
#  9   rating            50000 non-null  float64
#  10  review_count      50000 non-null  int64
#  11  discounted_price  50000 non-null  float64
#  12  total_revenue     50000 non-null  float64
# dtypes: datetime64[us](1), float64(4), int64(5), str(3)
# memory usage: 5.0 MB
#             order_id                  order_date    product_id  \
# ...

# %%
# TODO: Check for missing values in your columns
df["price"].unique()
df.isna().sum().sort_values(ascending=False)
# Out:
# order_id            0
# order_date          0
# product_id          0
# product_category    0
# price               0
# discount_percent    0
# quantity_sold       0
# customer_region     0
# payment_method      0
# rating              0
# review_count        0
# discounted_price    0
# total_revenue       0
# dtype: int64

# %% [markdown]
# **Data Dictionary & Quality Check:**
# *Double click here to edit. For your key columns, answer:*
# 1. **Column Name:** [Price]
#    - **What it represents:** Price of the items
#    - **Data Type Issue?:** No issue was found
#    - **Sanity Check:** N/A
#    - **Missing Data Plan:** N/A

# %% [markdown]
# ## Part 3: Project Strategy (1.5 Points)
# Now that you have critically assessed your data quality, you must map it to your research goals that you indicated in Project Assignment #1.

# %% [markdown]
# **Research Questions:** *Double click here to edit.*
# 1. Which product categories perform best? - Columns needed: product_category, total_revenue, quantity_sold
# 2. Are ratings and review counts linked to higher sales? - Columns needed: rating, review_count, total_revenue, quantity_sold

# %% [markdown]
# **Statistical Analysis Plan:** *Double click here to edit*
#
# *Explain which statistical test (t-test, regression, etc.) you will use for each question and WHY.*
# will use descriptive statistics and grouping in pandas by calculating total revenue and total quantity sold for each product category, then ranking categories and visualizing results with bar charts. This approach directly answers which categories perform best because it compares category-level totals.
#
# I will test whether ratings and review counts are related to sales by calculating correlation between rating/review_count and both total_revenue and quantity_sold, and I may also run a simple linear regression to estimate how much sales change as ratings or review counts increase. Correlation and regression are appropriate because they measure and quantify relationships between numeric variables.

# %%
# TODO: Create a new dataframe containing ONLY the columns you need for your research.
# project_df = df[['col1', 'col2', ...]]
project_df = df[[
    "product_category",
    "total_revenue",
    "quantity_sold",
    "rating",
    "review_count"
]].copy()
# Out:
#   product_category  total_revenue  quantity_sold  rating  review_count
# 0            Books         463.52              4     3.5           443
# 1          Fashion        1210.40              5     3.7           475
# 2           Sports         793.28              2     4.4           183
# 3            Books        1264.64              4     5.0           212
# 4           Beauty         806.72              4     4.6           308

# %%
# TODO: Display the head of your new "focused" dataframe to verify it looks correct.
project_df.head()
# Out:
#   product_category  total_revenue  quantity_sold  rating  review_count
# 0            Books         463.52              4     3.5           443
# 1          Fashion        1210.40              5     3.7           475
# 2           Sports         793.28              2     4.4           183
# 3            Books        1264.64              4     5.0           212
# 4           Beauty         806.72              4     4.6           308
